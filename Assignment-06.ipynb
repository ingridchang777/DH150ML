# %%
#load data and libraries
import pandas as pd
trump_tweets = pd.read_csv('realDonaldTrump.csv',encoding='mac_roman')
obama_tweets = pd.read_csv('BarackObama.csv',encoding='mac_roman')

# %%
import nltk
from nltk.sentiment import vader
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/jovyan/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sia = vader.SentimentIntensityAnalyzer()

# %%
#define function that analyzes and returns the polarity score of the parameter
def getSentiment(review):
    return sia.polarity_scores(text)['compound']

# %%
trump_tweets.head()
# Out:
#        created_at                                               text  \
# 0  10/23/17 12:30  I had a very respectful conversation with the ...
# 1  10/23/17 11:53  Two dozen NFL players continue to kneel during...
# 2  10/23/17 11:42  There will be NO change to your 401(k). This h...
# 3  10/22/17 12:08  It is finally sinking through. 46% OF PEOPLE B...
# 4  10/22/17 12:02  Wacky Congresswoman Wilson is the gift that ke...
#
#                                                  url  replies  retweets  \
# 0  https://twitter.com/realDonaldTrump/status/922...    46228     10243
# 1  https://twitter.com/realDonaldTrump/status/922...    31419     14006
# 2  https://twitter.com/realDonaldTrump/status/922...     9552     13719
# 3  https://twitter.com/realDonaldTrump/status/922...    56238     25102
# 4  https://twitter.com/realDonaldTrump/status/922...    32136     21573
#
#    favorites             user
# 0      49468  realDonaldTrump
# 1      62406  realDonaldTrump
# ...

# %%
obama_tweets.head()
# Out:
#        created_at                                               text  \
# 0  10/16/17 22:59  I'm grateful to @SenJohnMcCain for his lifetim...
# 1   10/2/17 12:41  Michelle &amp; I are praying for the victims i...
# 2    9/30/17 2:22  Proud to cheer on Team USA at the Invictus Gam...
# 3   9/26/17 17:03  We're expanding our efforts to help Puerto Ric...
# 4   9/25/17 23:36  Prosecutor, soldier, family man, citizen. Beau...
#
#                                                  url  replies  retweets  \
# 0  https://twitter.com/BarackObama/status/9200615...    17064     89916
# 1  https://twitter.com/BarackObama/status/9148326...    21588    405895
# 2  https://twitter.com/BarackObama/status/9139520...     8476     60651
# 3  https://twitter.com/BarackObama/status/9127244...    10657    113807
# 4  https://twitter.com/BarackObama/status/9124608...     3886     58449
#
#    favorites         user
# 0     641842  BarackObama
# 1    1715753  BarackObama
# 2     503255  BarackObama
# ...

# %%
#create column VaderSentiment and populate it with the polarity score of each text
trump_tweets['VaderSentiment'] = [getSentimnt(text) for text in trump_tweets['text']]

# %%
trump_tweets
# Out:
#           created_at                                               text  \
# 0     10/23/17 12:30  I had a very respectful conversation with the ...
# 1     10/23/17 11:53  Two dozen NFL players continue to kneel during...
# 2     10/23/17 11:42  There will be NO change to your 401(k). This h...
# 3     10/22/17 12:08  It is finally sinking through. 46% OF PEOPLE B...
# 4     10/22/17 12:02  Wacky Congresswoman Wilson is the gift that ke...
# ...              ...                                                ...
# 3227   8/24/16 22:39  Thank you for your support!\r#AmericaFirst #Im...
# 3228   8/24/16 21:32  A great afternoon in Tampa, Florida. Thank you...
# 3229   8/24/16 17:24  New national poll released. Join the MOVEMENT ...
# 3230   8/24/16 16:42  Great new poll Florida - thank you! #MakeAmeri...
# 3231   8/24/16 15:19  I will not let the families of The Remembrance...
#
#                                                     url  replies  retweets  \
# ...

# %%
obama_tweets['VaderSentiment'] = [getSentiment(text) for text in obama_tweets['text']]

# %%
obama_tweets
# Out:
#           created_at                                               text  \
# 0     10/16/17 22:59  I'm grateful to @SenJohnMcCain for his lifetim...
# 1      10/2/17 12:41  Michelle &amp; I are praying for the victims i...
# 2       9/30/17 2:22  Proud to cheer on Team USA at the Invictus Gam...
# 3      9/26/17 17:03  We're expanding our efforts to help Puerto Ric...
# 4      9/25/17 23:36  Prosecutor, soldier, family man, citizen. Beau...
# ...              ...                                                ...
# 3202   8/15/14 20:16  Earning the minimum wage while raising a famil...
# 3203   8/15/14 18:02  FACT: 97% of scientists and NASA accept the sc...
# 3204   8/15/14 16:21  Getting covered made Jason so happy he wanted ...
# 3205   8/15/14 15:15  It's time to get serious and #ActOnClimate. ht...
# 3206   8/14/14 16:50  Happening now: President Obama is delivering a...
#
#                                                     url  replies  retweets  \
# ...

# %%
#calculate the total average of Trump's sentiment scores
trump_tweets['VaderSentiment'].mean()
# Out:
# 0.18796383044554543

# %%
#calculate the standard deviation of Trump's sentiment scores
trump_tweets['VaderSentiment'].std()
# Out:
# 0.5419582724540011

# %%
#calculate the total average of each president's sentiment scores
obama_tweets['VaderSentiment'].mean()
# Out:
# 0.19910617399438732

# %%
#calculate the standard deviation of Obama's sentiment scores
obama_tweets['VaderSentiment'].std()
# Out:
# 0.3787210150189972

# %%
#display a histogram plot showing the distribution of sentiment scores
trump_tweets['VaderSentiment'].hist()
# Out:
# <AxesSubplot:>

# %%
obama_tweets['VaderSentiment'].hist()
# Out:
# <AxesSubplot:>

# %%
#find the highest sentiment score (the most positive) of the Trump dataframe
trump_tweets['VaderSentiment'].max()
# Out:
# 0.9805

# %%
#find the tweet with the highest sentiment score
trump_tweets.loc[trump_tweets['VaderSentiment']== 0.9805]
# Out:
#        created_at                                               text  \
# 458  9/7/17 12:33  Hurricane Irma is raging but we have great tea...
#
#                                                    url  replies  retweets  \
# 458  https://twitter.com/realDonaldTrump/status/905...     6457     16565
#
#      favorites             user  VaderSentiment
# 458      82003  realDonaldTrump          0.9805

# %%
#read the full text
trump_tweets.iloc[458]['text']
# Out:
# 'Hurricane Irma is raging but we have great teams of talented and brave people already in place and ready to help. Be careful, be safe! #FEMA'

# %%
#find the lowest sentiment score (the most negative)
trump_tweets['VaderSentiment'].min()
# Out:
# -0.9735

# %%
#find the tweet with the lowest sentiment score
trump_tweets.loc[trump_tweets['VaderSentiment']== -0.9735]
# Out:
#          created_at                                               text  \
# 1431  4/18/17 10:38  Democrat Jon Ossoff would be a disaster in Con...
#
#                                                     url  replies  retweets  \
# 1431  https://twitter.com/realDonaldTrump/status/854...    12950     14207
#
#       favorites             user  VaderSentiment
# 1431      56073  realDonaldTrump         -0.9735

# %%
#read the full text
trump_tweets.iloc[1431]['text']
# Out:
# 'Democrat Jon Ossoff would be a disaster in Congress. VERY weak on crime and illegal immigration, bad for jobs and wants higher taxes. Say NO'

# %%
#repeat for the Obama dataframe
obama_tweets['VaderSentiment'].max()
# Out:
# 0.9349

# %%
obama_tweets.loc[obama_tweets['VaderSentiment']== 0.9349]
# Out:
#          created_at                                               text  \
# 723   3/27/16 17:43  "We wish all who celebrate a blessed and joyfu...
# 1618   8/4/15 21:13  Help President Obama celebrate another great y...
#
#                                                     url  replies  retweets  \
# 723   https://twitter.com/BarackObama/status/7141457...     1140      7866
# 1618  https://twitter.com/BarackObama/status/6286750...     1516      2382
#
#       favorites         user  VaderSentiment
# 723       32989  BarackObama          0.9349
# 1618       6101  BarackObama          0.9349

# %%
obama_tweets.iloc[723]['text']
# Out:
# '"We wish all who celebrate a blessed and joyful Easter." ‰ÛÓPresident Obama https://t.co/sSls4YLCYe'

# %%
obama_tweets.iloc[1618]['text']
# Out:
# 'Help President Obama celebrate another great year‰ÛÓwish him a happy birthday: http://t.co/CHVz44cTcH #44turns54 http://t.co/r8aa6ZgfRe'

# %%
obama_tweets['VaderSentiment'].min()
# Out:
# -0.9201

# %%
obama_tweets.loc[obama_tweets['VaderSentiment']== -0.9201]
# Out:
#         created_at                                               text  \
# 453  6/21/16 15:46  RT @POTUS: Gun violence requires more than mom...
#
#                                                    url  replies  retweets  \
# 453  https://twitter.com/BarackObama/status/7452818...     4272     64984
#
#      favorites         user  VaderSentiment
# 453     120391  BarackObama         -0.9201

# %%
obama_tweets.iloc[453]['text']
# Out:
# 'RT @POTUS: Gun violence requires more than moments of silence. It requires action. In failing that test, the Senate failed the American peo‰Û_'

# %%
#Obama's tweets had a slightly higher average VADER sentiment than that of Trump.
#Trump's tweets had a considerable higher standard deviation of sentiment than that of Obama.

#While both Obama and Trump's had a number of tweets fall as being slightly negative, the historgram shows that the majority of
#Trump's tweets had more tweets at the extreme ends of being positive or negative, while Obama had a majority as being
#fairly positive.

#All the texts predicted by the VADER sentiment scores were indeed extremely positive or negative. It even takes account
#of capitalization which amplifies the sentiment. By just looking at that, VADER appears to have done a fairly good job
#with evaluating these two datasets. 

#In some cases, negation, double negation, and especially compound sentences can result in the score falsely reflecting
#the actual sentiment of the text.

# %%
obama_tweets.sort_values(by=['retweets'])
# Out:
#           created_at                                               text  \
# 1260   11/9/15 19:49  RT @OFA: The #OFAFallSummit with @BarackObama ...
# 2949  10/10/14 15:53  RT @SmlBizMajority: #With1010, we could grow t...
# 983     1/13/16 2:50  RT @OFA: Hear some good ideas tonight? Show yo...
# 738    3/23/16 19:42  RT @SecBurwell: Because of the #ACA, insurance...
# 1872    6/23/15 0:11  RT @OFA_RI: Our state legislators and @GinaRai...
# ...              ...                                                ...
# 19      7/20/17 0:49  John McCain is an American hero &amp; one of t...
# 42     1/20/17 21:04  Hi everybody! Back to the original handle. Is ...
# 6       9/20/17 2:30  Thinking about our neighbors in Mexico and all...
# 17      8/13/17 0:06  "People must learn to hate, and if they can le...
# 18      8/13/17 0:06  "No one is born hating another person because ...
#
#                                                     url  replies  retweets  \
# ...

# %%
obama_tweets.sort_values(by=['replies'])
# Out:
#          created_at                                               text  \
# 2453   1/21/15 2:36  RT @OFA: If you're nodding your head during Pr...
# 991    1/13/16 2:43  RT @OFA: Climate action can no longer be pushe...
# 1016   1/13/16 2:20  RT @OFA: It's just called marriage now. #LoveI...
# 2444   1/21/15 2:47  RT @OFA: America should lead on science and te...
# 2472   1/21/15 2:20  RT @OFA: We‰Ûªve fought our way back from econ...
# ...             ...                                                ...
# 15    8/17/17 19:15  Michelle and I are thinking of the victims and...
# 19     7/20/17 0:49  John McCain is an American hero &amp; one of t...
# 13     9/5/17 18:52  To target hopeful young strivers who grew up h...
# 18     8/13/17 0:06  "No one is born hating another person because ...
# 42    1/20/17 21:04  Hi everybody! Back to the original handle. Is ...
#
#                                                     url  replies  retweets  \
# ...

# %%
#I was unable to get it to work, but I would like to sort the tweets by replies and retweets and examine if tweets with texts
#of more extreme and emotionally charged content, as evaluated by VADER, tend to get more interactions.
#I would also like to see how it differs between presidents, knowing that Former President Trump's tweets were especially
#polarizing

#If actual polarity score was available, I would be interested in evaluating how the VADER scores differs from the target.

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from string import punctuation

# %%
#create a list of all of Trump's tweets
trumpText =  list(trump_tweets["text"])

# %%
#create a list of stopwords
myStopWords = list(punctuation) + stopwords.words('english')

# %%
#I wanted to try adding "http" as a stopword after the first time I ran the model because it came up as a major
#keyword. However, my attempt to add it did not work
myStopWords.append("http")

# %%
#create a list of all words in Trump's tweets that are not in the stop words list
trumpDocs = []

for i in range(len(trumpText)):
    trumpDocs.append([w for w in word_tokenize(trumpText[i].lower()) if w not in myStopWords])

# %%
#view the words in the first doc
trumpDocs[0]
# Out:
# ['respectful',
#  'conversation',
#  'widow',
#  'sgt',
#  'la',
#  'david',
#  'johnson',
#  'spoke',
#  'name',
#  'beginning',
#  'without',
#  'hesitation']

# %%
from nltk.stem.porter import PorterStemmer

# %%
#create p_stemmer of class PorterStemmer
p_stemmer = PorterStemmer()

# %%
#create a stemmed version of the list of words
trump_docs_stemmed = []

for i in docs:
    trump_docs_stemmed.append([p_stemmer.stem(w) for w in i])

# %%
#view the stemmed version of Document 1's words
trump_docs_stemmed[0]
# Out:
# ['respect',
#  'convers',
#  'widow',
#  'sgt',
#  'la',
#  'david',
#  'johnson',
#  'spoke',
#  'name',
#  'begin',
#  'without',
#  'hesit']

# %%
from gensim import corpora, models
import gensim

# %%
#create a corpora dictionary
trumpDictionary = corpora.Dictionary(trump_docs_stemmed)

# %%
#filter the words that came up in more than 50% of the documents or less than 10%
trumpDictionary.filter_extremes(no_below=10, no_above=0.5)

# %%
#example of finding the id of a keyword
print(trumpDictionary.token2id['debatenight'])
# Out:
# 749

# %%
#match the id to the keyword to verify dictionary is set up correctly
trumpDictionary[749]
# Out:
# 'debatenight'

# %%
#create corpus
trump_corpus = [trumpDictionary.doc2bow(text) for text in trump_docs_stemmed]

# %%
#run the LDA model with 20 topics and 20 passes
ldamodel = gensim.models.ldamodel.LdaModel(trump_corpus, 
                                           num_topics=20, 
                                           id2word = trumpDictionary, 
                                           passes=20)

# %%
#show most important words for each topic identified
for i in ldamodel.print_topics(num_topics=20, num_words=20):
    print(i[0])
    print(i[1])
    print('\n')
# Out:
# 0
# 0.107*"draintheswamp" + 0.074*"http" + 0.056*"enjoy" + 0.051*"interview" + 0.051*"time" + 0.041*"tonight" + 0.032*"everyon" + 0.027*"foxnew" + 0.024*"market" + 0.023*"new" + 0.021*"care" + 0.020*"year" + 0.020*"sinc" + 0.019*"p.m." + 0.019*"court" + 0.019*"icymi" + 0.018*"stock" + 0.018*"high" + 0.015*"hope" + 0.014*"israel"
#
#
# 1
# 0.044*"obamacar" + 0.033*"replac" + 0.031*"amp" + 0.031*"must" + 0.030*"repeal" + 0.029*"talk" + 0.024*"want" + 0.024*"attack" + 0.022*"year" + 0.022*"...." + 0.022*"disast" + 0.020*"democrat" + 0.019*"n't" + 0.018*"compani" + 0.017*"dollar" + 0.016*"fix" + 0.016*"http" + 0.015*"action" + 0.014*"terrorist" + 0.013*"immigr"
#
#
# 2
# ...

# %%
import matplotlib.pyplot as plt
import re

# %%
#configure re
re.split(re.escape(' + ') + '|' + re.escape('*'), 'hi + me*4')
# Out:
# ['hi', 'me', '4']

# %%
#display the 20 topics
fig,ax = plt.subplots(5,4,figsize=(15,20))
ax = ax.flatten()
for i in ldamodel.print_topics(num_topics=20, num_words=20):
    x = []
    y = []
    count = 0
    for j in re.split(re.escape(' + ') + '|' + re.escape('*'), i[1]):
        if count % 2 == 0:
            y.insert(0,float(j))
        else:
            x.insert(0,j)
        count += 1
    ax[i[0]].barh(x,y,height=0.5)
plt.tight_layout()

# %%
#run the LDA model with 30 topics and 50 passes
ldamodel = gensim.models.ldamodel.LdaModel(corpus, 
                                           num_topics=30, 
                                           id2word = trumpDictionary, 
                                           passes=50)

# %%
#show most important words for each topic identified
for i in ldamodel.print_topics(num_topics=30, num_words=50):
    print(i[0])
    print(i[1])
    print('\n')
# Out:
# 0
# 0.157*"great" + 0.123*"america" + 0.122*"make" + 0.054*"ohio" + 0.052*"thank" + 0.051*"http" + 0.046*"togeth" + 0.038*"countri" + 0.032*"safe" + 0.031*"go" + 0.024*"americafirst" + 0.014*"support" + 0.013*"amaz" + 0.012*"nfl" + 0.010*"proud" + 0.010*"first" + 0.010*"disrespect" + 0.009*"player" + 0.009*"respond" + 0.009*"regul" + 0.008*"game" + 0.008*"anthem" + 0.008*"flag" + 0.007*"start" + 0.007*"love" + 0.006*"governor" + 0.006*"put" + 0.006*"brave" + 0.005*"god" + 0.005*"bless" + 0.005*"incred" + 0.005*"see" + 0.005*"everyon" + 0.004*"readi" + 0.004*"crowd" + 0.004*"begin" + 0.004*"get" + 0.004*"leav" + 0.004*"total" + 0.004*"servic" + 0.004*"fema" + 0.003*"nation" + 0.003*"militari" + 0.003*"futur" + 0.003*"forget" + 0.003*"chang" + 0.003*"way" + 0.002*"continu" + 0.002*"justic" + 0.002*"campaign"
#
#
# 1
# ...

# %%
#display the 30 topics
fig,ax = plt.subplots(5,4,figsize=(15,20))
ax = ax.flatten()
for i in ldamodel.print_topics(num_topics=30, num_words=20):
    x = []
    y = []
    count = 0
    for j in re.split(re.escape(' + ') + '|' + re.escape('*'), i[1]):
        if count % 2 == 0:
            y.insert(0,float(j))
        else:
            x.insert(0,j)
        count += 1
    ax[i[0]].barh(x,y,height=0.5)
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_56/2970431769.py in <module>
#      12             x.insert(0,j)
#      13         count += 1
# ---> 14     ax[i[0]].barh(x,y,height=0.5)
#      15 plt.tight_layout()
#
# IndexError: index 20 is out of bounds for axis 0 with size 20

# %%
#create a list of all of Obama's tweets
obamaText =  list(obama_tweets["text"])

# %%
#create a list of all words in Obama's tweets that are not in the stop words list
obamaDocs = []

# %%
for i in range(len(obamaText)):
    obamaDocs.append([w for w in word_tokenize(obamaText[i].lower()) if w not in myStopWords])

# %%
#view the words in the first doc
obamaDocs[0]
# Out:
# ["'m",
#  'grateful',
#  'senjohnmccain',
#  'lifetime',
#  'service',
#  'country',
#  'congratulations',
#  'john',
#  'receiving',
#  'year',
#  "'s",
#  'liberty',
#  'medal']

# %%
#create a stemmed version of the list of words
obama_docs_stemmed = []

# %%
for i in obamaDocs:
    obama_docs_stemmed.append([p_stemmer.stem(w) for w in i])

# %%
#view the stemmed version of Document 0's words
obama_docs_stemmed[0]
# Out:
# ["'m",
#  'grate',
#  'senjohnmccain',
#  'lifetim',
#  'servic',
#  'countri',
#  'congratul',
#  'john',
#  'receiv',
#  'year',
#  "'s",
#  'liberti',
#  'medal']

# %%
#create a corpora dictionary
obamaDictionary = corpora.Dictionary(obama_docs_stemmed)

# %%
#filter the words that came up in more than 50% of the documents or less than 10%
obamaDictionary.filter_extremes(no_below=10, no_above=0.5)

# %%
#create corpus
obama_corpus = [obamaDictionary.doc2bow(text) for text in obama_docs_stemmed]

# %%
#run the LDA model with 20 topics and 20 passes
ldamodel = gensim.models.ldamodel.LdaModel(obama_corpus, 
                                           num_topics=20, 
                                           id2word = obamaDictionary, 
                                           passes=20)

# %%
#show most important words for each topic identified
for i in ldamodel.print_topics(num_topics=20, num_words=20):
    print(i[0])
    print(i[1])
    print('\n')
# Out:
# 0
# 0.123*"job" + 0.109*"economi" + 0.088*"year" + 0.048*"month" + 0.046*"new" + 0.038*"pollut" + 0.035*"growth" + 0.030*"ad" + 0.030*"sinc" + 0.029*"carbon" + 0.027*"record" + 0.027*"cut" + 0.024*"'s" + 0.022*"private-sector" + 0.022*"grow" + 0.020*"last" + 0.020*"busi" + 0.018*"actonclim" + 0.017*"six" + 0.017*"creat"
#
#
# 1
# 0.084*"'s" + 0.075*"progress" + 0.053*"econom" + 0.049*"let" + 0.041*"keep" + 0.040*"work" + 0.036*"back" + 0.030*"go" + 0.030*"http" + 0.028*"way" + 0.025*"made" + 0.024*"2015" + 0.022*"build" + 0.021*"fight" + 0.020*"part" + 0.020*"'re" + 0.019*"readi" + 0.018*"help" + 0.016*"everyon" + 0.015*"economi"
#
#
# 2
# 0.133*"'s" + 0.108*"time" + 0.081*"name" + 0.069*"add" + 0.062*"day" + 0.044*"women" + 0.035*"think" + 0.033*"pay" + 0.030*"unit" + 0.030*"state" + 0.026*"agre" + 0.026*"equal" + 0.024*"work" + 0.023*"expand" + 0.019*"worker" + 0.017*"get" + 0.017*"american" + 0.016*"left" + 0.015*"five" + 0.013*"full"
#
#
# 3
# ...

# %%
#display the 20 topics
fig,ax = plt.subplots(5,4,figsize=(15,20))
ax = ax.flatten()
for i in ldamodel.print_topics(num_topics=20, num_words=20):
    x = []
    y = []
    count = 0
    for j in re.split(re.escape(' + ') + '|' + re.escape('*'), i[1]):
        if count % 2 == 0:
            y.insert(0,float(j))
        else:
            x.insert(0,j)
        count += 1
    ax[i[0]].barh(x,y,height=0.5)
plt.tight_layout()

# %%
#run the LDA model with 30 topics and 50 passes
ldamodel = gensim.models.ldamodel.LdaModel(obama_corpus, 
                                           num_topics=30, 
                                           id2word = obamaDictionary, 
                                           passes=50)

# %%
#show most important words for each topic identified
for i in ldamodel.print_topics(num_topics=30, num_words=20):
    print(i[0])
    print(i[1])
    print('\n')
# Out:
# 0
# 0.221*"``" + 0.215*"''" + 0.198*"‰ûópresid" + 0.198*"obama" + 0.026*"america" + 0.019*"sotu" + 0.015*"american" + 0.008*"busi" + 0.008*"go" + 0.007*"creat" + 0.006*"know" + 0.006*"everybodi" + 0.006*"‰ûó" + 0.005*"year" + 0.005*"young" + 0.005*"new" + 0.004*"past" + 0.004*"idea" + 0.004*"action" + 0.004*"women"
#
#
# 1
# 0.111*"wage" + 0.097*"good" + 0.096*"raisethewag" + 0.086*"rais" + 0.083*"minimum" + 0.056*"american" + 0.047*"'s" + 0.045*"worker" + 0.035*"amp" + 0.034*"assault" + 0.034*"work" + 0.029*"famili" + 0.026*"poverti" + 0.022*"support" + 0.021*"latest" + 0.020*"chicago" + 0.016*"mark" + 0.015*"time" + 0.013*"op-" + 0.010*"check"
#
#
# 2
# ...

# %%
#display the 30 topics
fig,ax = plt.subplots(5,4,figsize=(15,20))
ax = ax.flatten()
for i in ldamodel.print_topics(num_topics=30, num_words=20):
    x = []
    y = []
    count = 0
    for j in re.split(re.escape(' + ') + '|' + re.escape('*'), i[1]):
        if count % 2 == 0:
            y.insert(0,float(j))
        else:
            x.insert(0,j)
        count += 1
    ax[i[0]].barh(x,y,height=0.5)
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_56/2970431769.py in <module>
#      12             x.insert(0,j)
#      13         count += 1
# ---> 14     ax[i[0]].barh(x,y,height=0.5)
#      15 plt.tight_layout()
#
# IndexError: index 20 is out of bounds for axis 0 with size 20

# %%
#Looking at the LDA model, it is interesting to notice the refinement of keywords when the number
#of topics and number of passes were increased. At the same time, even though the words were more complete,
#the grouping of the keywords by topic made less sense to me. However, it filtered out filler much more text,
#like "http" which indicated linking of websites. All in all, the increased passes reflected more substance

#It was also very interesting to see the difference between the grouping of Obama and Trump's tweets. Both
#being presidents during terms that faced many similar issues, they shared many of the same keywords.
#However, the grouping of the words and the other keywords that showed up in each president's discussion of
#these topics were dramatically different.
#For example, Trump had a topic probably about the Democratic party. The keywords for that obamacare, democrats,
#terrorism, disaster, immigration, and repeal. Obama does not seem to call out and criticize the Republican Party
#as frequently, especially in terms of attributing. The model was also able to pick up on Trump's famous name-calling
#and unique diction. Under a topic about "clinton," presumably Hilary clinton, keywords of crooked, bernie, and drain
#the swamp was found. Under "make american great", republican state names, beautiful, and big were found.
#Under "news," fake, media, fail, bad, elect, report, new york times, and russia were found

#Trump was particularly known for his slogans and unique word choices, and the model captured them well. Obama
#was not as distinct, but recurring themes in his presidency did show up, such as the topic economy, which was
#associated with words about business, and year. In adovocating for civil rights, equal, pay, woman, and unite
#were reflected and unifying efforts included keywods of educate, world, people, and health

#I did not expect and was very pleasantly surprised by my model's ability to eluciate and highlight this difference.
